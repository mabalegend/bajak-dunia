# %%
import twint
import nest_asyncio
# Out:
# Traceback (most recent call last):
#
#   File "c:\users\damzaky\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-bb8aad6a58dc>", line 1, in <module>
#     import twint
#
#   File "D:\PROJECTS\repo batur\twint other\twint\twint\__init__.py", line 14, in <module>
#     from . import run
#
#   File "D:\PROJECTS\repo batur\twint other\twint\twint\run.py", line 261
#     if not tweets_replier:
#     ^
# IndentationError: unexpected unindent

# %%
nest_asyncio.apply()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d857ce299ed7> in <module>
# ----> 1 nest_asyncio.apply()
#
# NameError: name 'nest_asyncio' is not defined

# %%
c = twint.Config()
c.Search = "rasis lu"
c.Lang = "id"
c.Near = "bandung"
c.Store_object = True
c.Limit = 20
twint.run.Search(c)
tlist = c.search_tweet_list

# %%
tlist #[0]['parent_tweets'][0]
# Out:
# [{'parent_tweets': [<table class="tweet" href="/kumparan/status/1309830351447965697?p=v">
#    <tr class="tweet-header">
#    <td class="avatar" rowspan="3">
#    <a href="/kumparan?p=i">
#    <img alt="kumparan" src="https://pbs.twimg.com/profile_images/1298406004292345856/PIzFTNo-_normal.jpg"/>
#    </a>
#    </td>
#    <td class="user-info">
#    <a href="/kumparan?p=s">
#    <strong class="fullname">kumparan</strong>
#    <div class="username">
#    <span>@</span>kumparan
#        </div>
#    </a>
#    </td>
#    <td class="timestamp">
#    <a href="/kumparan/status/1309830351447965697?p=p" name="tweet_1309830351447965697">Sep 26</a>
#    </td>
#    </tr>
#    <tr class="tweet-container">
#    <td class="tweet-content" colspan="2">
#    <div class="tweet-text" data-id="1309830351447965697">
# ...

# %%
tlist[0]
# Out:
# '<'

# %%
test = []

# %%
test[-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-a7b63ba1c801> in <module>
# ----> 1 test[-1]
#
# IndexError: list index out of range
